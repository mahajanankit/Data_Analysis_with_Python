# %% [markdown]
# # Question8

# %%
import nltk
from nltk.corpus import nps_chat
from nltk.corpus import words

# %%
#collection words
enwords = words.words('en')
chatwords = nps_chat.words()

# %%
#revomving duplicates
enwords = set(enwords)
chatwords = set(chatwords)

# %%
#Calculating unmatched words
cwords = []
for w in chatwords:
    if w.lower() in enwords:
        continue
    else:
        cwords.append(w)
# Out:
# 10
# bachelorette
# kisses
# raarrrrrr
# pppppppppppew
# yoll
# ok'd
# Metallica
# outta
# WEEEEEEEEEEEEEEEEEE
# hunters
# heeeey
# HOTT
# Box
# llloooozzzzeeerrrrzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# waits
# gurlie
# exchanging
# alterz
# pictures
# kneess
# LoL
# lotsa
# hoo
# 1985
# chineese
# beeeeehave
# SHOWS
# cmon
# yepper
# cams
# h.s
# boys
# oooooooooooo
# othing
# yards
# FreesBee
# sayn
# burried
# awesomee
# U153
# :p
# *VBS*
# thoughts
# hoping
# cnnecticut
# 37
# Heys
# $27
# commanded
# geeshhh
# norny
# paints
# U542
# ((((((((((((
# obbts
# yvw
# pfft
# prittier
# chics
# fuck
# cool1024
# sits
# inhales
# U50
# U33
# hgfhgfjgf
# Kansas
# cuz
# mena
# ussy
# lb
# EST
# hiiii
# awwww
# ??
# )))))))))))))))
# lambergini
# retared
# im
# stans
# sleeps
# mmmmk
# bloe
# fock
# allo
# :(
# goths
# .....
# 8082653953
# aynawy
# hahahahahahaha
# fillin
# 98.6
# temples
# babycakeses
# lets
# <333
# myspace.com
# hahahahahaha
# boooooooooooglyyyyyy
# psh
# ...

# %%
cwords
# Out:
# ['',
#  '10',
#  'bachelorette',
#  'kisses',
#  'raarrrrrr',
#  'pppppppppppew',
#  'yoll',
#  "ok'd",
#  'Metallica',
#  'outta',
#  'WEEEEEEEEEEEEEEEEEE',
#  'hunters',
#  'heeeey',
#  'HOTT',
#  'Box',
#  'llloooozzzzeeerrrrzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#  'waits',
#  'gurlie',
#  'exchanging',
#  'alterz',
#  'pictures',
#  'kneess',
#  'LoL',
#  'lotsa',
#  'hoo',
#  '1985',
#  'chineese',
#  'beeeeehave',
#  'SHOWS',
#  'cmon',
#  'yepper',
#  'cams',
#  'h.s',
#  'boys',
#  'oooooooooooo',
#  'othing',
#  'yards',
#  'FreesBee',
#  'sayn',
#  'burried',
#  'awesomee',
#  'U153',
#  ':p',
#  '*VBS*',
#  'thoughts',
#  'hoping',
#  'cnnecticut',
#  '37',
#  'Heys',
#  '$27',
#  'commanded',
#  'geeshhh',
#  'norny',
#  'paints',
#  'U542',
#  '((((((((((((',
#  'obbts',
#  'yvw',
#  'pfft',
#  'prittier',
#  'chics',
#  'fuck',
#  'cool1024',
#  'sits',
#  'inhales',
#  'U50',
#  'U33',
#  'hgfhgfjgf',
#  'Kansas',
#  'cuz',
#  'mena',
#  'ussy',
#  'lb',
# ...

# %% [markdown]
# Output:

# %%
print("Total number of unusual words are: ",len(cwords))
# Out:
# Total number of unusual words are:  3020
